# %%
import pandas as pd
import numpy as np
from budget_constraints import BudgetConstraints
import warnings

warnings.filterwarnings('ignore')

# %%
bc = BudgetConstraints(utility_func='cb', params=[0.3, 0.7], endowment=20, prices=[1,3])

# %%
#drawing the budget line
bc.budget_line()

# %%
#draw a random indifference curve
bc.indff_curve()

# %%
#find the optimal allocation
bc.optimal_allocation()
# Out:
# Max utility = 5.032109950568678
