# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from edgeworth_class import EdgeworthBox

warnings.filterwarnings('ignore')

# %% [markdown]
# ### This Notebook is built solely for demonstration purposes. How to use this package.

# %%
edg_box = EdgeworthBox(type1='linear', params1= [0.5, 0.5], type2='cb', params2 =[2,3], endowment1=[2,7], endowment2=[7,3])

# %%
edg_box = EdgeworthBox(type1='linear', params1= [0.5, 0.5], type2='cb', params2 =[2,3], endowment1=[2,7], endowment2=[7,3])
fig, ax = plt.subplots(1,1, figsize=(12,6))
edg_box.plot_all(ax)

# %%
fig, ax = plt.subplots(3,2, figsize=(15,20))
edg_box0 = EdgeworthBox(type1='cb', params1= [0.7, 0.3], type2='cb', params2 =[0.2,0.8], endowment1=[2,7], endowment2=[7,3])
edg_box0.plot_all(ax[0,0], show=False)

edg_box1 = EdgeworthBox(type1='cb', params1= [0.7, 0.3], type2='leontieff', params2 =[3,4], endowment1=[2,7], endowment2=[7,3])
edg_box1.plot_all(ax[0,1], show=False)

edg_box2 = EdgeworthBox(type1='cb', params1= [0.7, 0.3], type2='linear', params2 =[0.2,0.8], endowment1=[2,7], endowment2=[7,3])
edg_box2.plot_all(ax[1,0], show=False)

edg_box3 = EdgeworthBox(type1='linear', params1= [0.7, 0.3], type2='linear', params2 =[0.2,0.8], endowment1=[2,7], endowment2=[7,3])
edg_box3.plot_all(ax[1,1], show=False)

edg_box4 = EdgeworthBox(type1='linear', params1= [0.7, 0.3], type2='leontieff', params2 =[2,5], endowment1=[2,7], endowment2=[7,3])
edg_box4.plot_all(ax[2,0], show=False)

edg_box5 = EdgeworthBox(type1='leontieff', params1= [1, 3], type2='leontieff', params2 =[4,2], endowment1=[2,7], endowment2=[7,3])
edg_box5.plot_all(ax[2,1])
